# %%
from model import bptk

# %%
bptk.plot_scenarios(
    scenario_managers=["smSir"],
    scenarios=["strong_social_distancing"],
    equations=["contact_rate"]
)

# %%
bptk.plot_scenarios(
    scenario_managers=["smSir"],
    scenarios=["strong_social_distancing"],
    equations=["intensive_needed","intensive_available"]
)

# %%
bptk.plot_scenarios(
    scenario_managers=["smSir"],
    scenarios=["weak_social_distancing"],
    equations=["contact_rate"]
)

# %%
bptk.plot_scenarios(
    scenario_managers=["smSir"],
    scenarios=["weak_social_distancing"],
    equations=["intensive_needed","intensive_available"]
)

# %%
bptk.plot_scenarios(
    scenario_managers=["smSir"],
    scenarios=["isolation"],
    equations=["contact_rate"]
)

# %%
bptk.plot_scenarios(
    scenario_managers=["smSir"],
    scenarios=["avoid_the_peak"],
    equations=["contact_rate"]
)

# %%
bptk.plot_scenarios(
    scenario_managers=["smSir"],
    scenarios=["avoid_the_peak"],
    equations=["intensive_needed","intensive_available"]
)

# %%
bptk.plot_scenarios(
    scenario_managers=["smSir"],
    scenarios=["avoid_the_peak"],
    equations=["recovered"]
)
